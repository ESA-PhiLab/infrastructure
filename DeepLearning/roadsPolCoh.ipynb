# %% [markdown]
# ## Imports

# %%
# Set GPUs to use
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=4
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=4

# %%
# Standard data science imports
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.io import imsave
import h5py
import rasterio

# Import class to split image into smaller tiles from 
# https://github.com/ESA-PhiLab/eo4ai/tree/master/eo4ai/utils
from splitters import * 

# Tensorflow and Keras
from tensorflow.keras.models import Model, load_model
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras import optimizers
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Set Directories

# %%
# Directories
pol_path = r'/home/stewartchris/project/S1/data/S1_S0_TC_stack_mean_dB_W_UTM_AOI_clip.tif'
coh_path = r'/home/stewartchris/project/S1/data/coh_ML_TC_mean5_20191101_20191231_AOI_W_sameRes.tif'
mask_path = r'/home/stewartchris/project/S1/data/S1_S0_TC_stack_mean_dB_W_UTM_AOI_mask_clip.tif'
model_path = r'/home/stewartchris/project/S1/models/roadModelDataAugPolCoh.h5'
pred_path = r'/home/stewartchris/project/S1/data/predictionPolCoh.tif'

# %% [markdown]
# ## Read Data and Preprocess

# %%
# read in data
pol_orig = imread(pol_path, key=0)
coh_orig = imread(coh_path, key=0)
mask_orig = imread(mask_path, key=0)

# merge polarimetric and coherence channels into rgb
band_orig = np.zeros((pol_orig.shape[0],pol_orig.shape[1],pol_orig.shape[2]+1))
band_orig[:,:,0:2] = pol_orig
band_orig[:,:,2] = coh_orig

# %%
# apply sliding window splitter, need to import splitter.py from 
# https://github.com/ESA-PhiLab/eo4ai/tree/master/eo4ai/utils

# SET WINDOW SIZE
window = 128

mask_3d = mask_orig[..., np.newaxis]
splitter = SlidingWindowSplitter(window, window) # from splitter.py
bands_patches, mask_patches, patch_ids = splitter(band_orig, mask_3d)

bpatches = np.array(bands_patches)
mpatches = np.array(mask_patches)
ipatches = np.array(patch_ids)

# %%
# mask out pixels where no data (0 in polarimetric and coherence)

bpatchesSum = np.sum(bpatches, axis=3)
zeroTest = np.all(bpatchesSum, axis=(1,2))
indices = np.where(zeroTest == True)
indices = indices[0]
sents = bpatches[(indices), ...].copy()
masks = mpatches[(indices), ...].copy()
ids = ipatches[(indices), ...].copy()

# %%
# mask out pixels where no Open Street Map

masksFlat = masks.reshape((masks.shape[0]), window*window)
index = np.where(np.sum(masksFlat, axis=1) > 0)
index = np.squeeze(np.array(index))

sents = sents[index, ...]
masks = masks[index, ...]
ids = ids[index, ...]

# %%
# normalise data from dB to range(0, 1)
sentsMin = np.amin(sents, axis=(0,1,2))
sentsMax = np.amax(sents, axis=(0,1,2))
sents = (sents - sentsMin) / (sentsMax - sentsMin)

# %%
print('The number of samples are:', sents.shape[0])
# Out:
# The number of samples are: 767

# %% [markdown]
# #### Inspect Data

# %%
plt.imshow(sents[3,:,:,2], cmap='gray')

# %%
plt.imshow(masks[3,:,:,0], cmap='gray')

# %%
# split train and test data
train_size = int(sents.shape[0] * 0.8)
val_size = int(sents.shape[0] * 0.9)

sentTrain = sents[:train_size, ...]
maskTrain = masks[:train_size, ...]
idsTrain = ids[:train_size, ...]

sentVal = sents[train_size:val_size, ...]
maskVal = masks[train_size:val_size, ...]
idsVal = ids[train_size:val_size, ...]

sentTest = sents[val_size:, ...]
maskTest = masks[val_size:, ...]
idsTest = ids[val_size:, ...]

# %% [markdown]
# ## Data Augmentation

# %%
data_gen_args = dict(
    rotation_range=360,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect'
)

# Fill modes:
#'constant': kkkkkkkk|abcd|kkkkkkkk (cval=k)
#'nearest': aaaaaaaa|abcd|dddddddd
#'reflect': abcddcba|abcd|dcbaabcd
#'wrap': abcdabcd|abcd|abcdabcd

# %% [markdown]
# ### Visualise Augmented Data

# %%
from numpy import expand_dims

# %% [markdown]
# #### View original image and mask

# %%
index_to_view = 3

# %%
plt.imshow(np.squeeze(sentTrain[index_to_view]))

# %%
plt.imshow(np.squeeze(maskTrain[index_to_view]), cmap='gray')

# %% [markdown]
# #### View augmented images, applied to original

# %%
Ss = expand_dims(sentTrain[index_to_view],0)
Ms = expand_dims(maskTrain[index_to_view],0)

# %%
datagen = ImageDataGenerator(rotation_range=360, horizontal_flip=True, vertical_flip=True, fill_mode='reflect')
Sa = datagen.flow(Ss, batch_size=1, seed=1)
Ma = datagen.flow(Ms, batch_size=1, seed=1)

plt.figure(figsize=(20, 18))
for i in range(8):
    plt.subplot(4,4,1 + i)
    Sa_batch = Sa.next()
    plt.imshow(np.squeeze(Sa_batch), cmap='gray')
    plt.subplot(4,4,1 + i+8)
    Ma_batch = Ma.next()
    Ma_batch[Ma_batch > 0] = 1
    Ma_batch = Ma_batch.astype(bool)
    plt.imshow(np.squeeze(Ma_batch), cmap='gray')

# %% [markdown]
# ## Define Hyperparameters and Data Generators

# %%
# Hyperparameters
EPOCHS = 100
STEPS_PER_EPOCH = 100
LEARNING_RATE = 0.0001
BATCH_SIZE = 64

# %%
def trainGenerator(batch_size, train_data, mask_data, aug_dict, seed):
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow(train_data, batch_size = batch_size, seed = seed)
    mask_generator = mask_datagen.flow(mask_data, batch_size = batch_size, seed = seed)
    train_generator = zip(image_generator, mask_generator)
    for (img,mas) in train_generator:
        mas[mas > 0] = 1
        mas = mas.astype(bool)
        yield (img,mas)

# %%
trainGene = trainGenerator(BATCH_SIZE, sentTrain, maskTrain, data_gen_args, 1)

# %%
def valGenerator(batch_size, val_data, val_mask_data, seed):
    image_generator = ImageDataGenerator().flow(val_data, batch_size = batch_size, seed = seed)
    mask_generator = ImageDataGenerator().flow(val_mask_data, batch_size = batch_size, seed = seed)
    val_generator = zip(image_generator, mask_generator)
    for (img,mas) in val_generator:
        mas[mas > 0] = 1
        mas = mas.astype(bool)
        yield (img,mas)

# %%
valGene = valGenerator(1, sentVal, maskVal, 1)

# %% [markdown]
# ## Define U-Net Deep Learning Model for Image Segmentation

# %%
# define accuracy metric
#Source: https://towardsdatascience.com/metrics-to-evaluate-your-semantic-segmentation-model-6bcb99639aa2
from tensorflow.keras import backend as K
def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  
  return iou

# %%
# define loss function
def dice_coef(y_true, y_pred, smooth = 1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def soft_dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
# define U-Net model
inputs = Input((window, window, 3))

conv1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (inputs)
conv1 = BatchNormalization() (conv1)
conv1 = Dropout(0.1) (conv1)
conv1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv1)
conv1 = BatchNormalization() (conv1)
pooling1 = MaxPooling2D((2, 2)) (conv1)

conv2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling1)
conv2 = BatchNormalization() (conv2)
conv2 = Dropout(0.1) (conv2)
conv2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv2)
conv2 = BatchNormalization() (conv2)
pooling2 = MaxPooling2D((2, 2)) (conv2)

conv3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling2)
conv3 = BatchNormalization() (conv3)
conv3 = Dropout(0.2) (conv3)
conv3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv3)
conv3 = BatchNormalization() (conv3)
pooling3 = MaxPooling2D((2, 2)) (conv3)

conv4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling3)
conv4 = BatchNormalization() (conv4)
conv4 = Dropout(0.2) (conv4)
conv4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv4)
conv4 = BatchNormalization() (conv4)
pooling4 = MaxPooling2D(pool_size=(2, 2)) (conv4)

conv5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling4)
conv5 = BatchNormalization() (conv5)
conv5 = Dropout(0.3) (conv5)
conv5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv5)
conv5 = BatchNormalization() (conv5)


upsample6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (conv5)
upsample6 = concatenate([upsample6, conv4])
conv6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample6)
conv6 = BatchNormalization() (conv6)
conv6 = Dropout(0.2) (conv6)
conv6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv6)
conv6 = BatchNormalization() (conv6)

upsample7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (conv6)
upsample7 = concatenate([upsample7, conv3])
conv7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample7)
conv7 = BatchNormalization() (conv7)
conv7 = Dropout(0.2) (conv7)
conv7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv7)
conv7 = BatchNormalization() (conv7)

upsample8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (conv7)
upsample8 = concatenate([upsample8, conv2])
conv8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample8)
conv8 = BatchNormalization() (conv8)
conv8 = Dropout(0.1) (conv8)
conv8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv8)
conv8 = BatchNormalization() (conv8)

upsample9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (conv8)
upsample9 = concatenate([upsample9, conv1], axis=3)
conv9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample9)
conv9 = BatchNormalization() (conv9)
conv9 = Dropout(0.1) (conv9)
conv9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv9)
conv9 = BatchNormalization() (conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (conv9)

model = Model(inputs=[inputs], outputs=[outputs])
model.summary()
# Out:
# W0218 16:08:12.565189 140716447069696 deprecation.py:506] From /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1633: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 256)    1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 256)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 256)    1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 128)  131200      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 256)  0           conv2d_transpose[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 64)   32832       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 32)   8224        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 32)   9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 16) 2064        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 16) 64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 16) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 16) 2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 1)  17          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 1,946,993
# Trainable params: 1,944,049
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
# Compile the model
opt = tf.keras.optimizers.Adam(LEARNING_RATE)
model.compile(
      optimizer=opt,
      loss=soft_dice_loss,
      metrics=[iou_coef])

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### With Data Augmentation

# %%
# Train the model with data augmentation
history = model.fit_generator(
    trainGene, 
    steps_per_epoch=STEPS_PER_EPOCH, 
    epochs=EPOCHS,
    validation_data=valGene,
    validation_steps=sentVal.shape[0]
)
# Out:
# Epoch 1/100
# W0218 16:09:58.784988 140716447069696 deprecation.py:323] From /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py:468: BaseResourceVariable.constraint (from tensorflow.python.ops.resource_variable_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Apply a constraint manually following the optimizer update step.
# 100/100 [==============================] - 38s 379ms/step - loss: 0.9391 - iou_coef: 0.0355 - val_loss: 0.9662 - val_iou_coef: 0.0180
# Epoch 2/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.9214 - iou_coef: 0.0486 - val_loss: 0.9802 - val_iou_coef: 0.0106
# Epoch 3/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.9106 - iou_coef: 0.0556 - val_loss: 0.9794 - val_iou_coef: 0.0110
# Epoch 4/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.9013 - iou_coef: 0.0619 - val_loss: 0.9504 - val_iou_coef: 0.0264
# Epoch 5/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.8929 - iou_coef: 0.0659 - val_loss: 0.9361 - val_iou_coef: 0.0337
# Epoch 6/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.8830 - iou_coef: 0.0701 - val_loss: 0.9388 - val_iou_coef: 0.0321
# Epoch 7/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.8731 - iou_coef: 0.0727 - val_loss: 0.9260 - val_iou_coef: 0.0392
# Epoch 8/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.8630 - iou_coef: 0.0777 - val_loss: 0.9219 - val_iou_coef: 0.0414
# Epoch 9/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.8502 - iou_coef: 0.0830 - val_loss: 0.9210 - val_iou_coef: 0.0420
# Epoch 10/100
# 100/100 [==============================] - 32s 325ms/step - loss: 0.8380 - iou_coef: 0.0884 - val_loss: 0.9119 - val_iou_coef: 0.0468
# Epoch 11/100
# 100/100 [==============================] - 33s 325ms/step - loss: 0.8241 - iou_coef: 0.0957 - val_loss: 0.9025 - val_iou_coef: 0.0523
# Epoch 12/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.8099 - iou_coef: 0.1026 - val_loss: 0.9139 - val_iou_coef: 0.0459
# Epoch 13/100
# 100/100 [==============================] - 33s 327ms/step - loss: 0.7941 - iou_coef: 0.1108 - val_loss: 0.9026 - val_iou_coef: 0.0521
# Epoch 14/100
# 100/100 [==============================] - 33s 327ms/step - loss: 0.7775 - iou_coef: 0.1189 - val_loss: 0.9063 - val_iou_coef: 0.0502
# Epoch 15/100
# 100/100 [==============================] - 32s 324ms/step - loss: 0.7612 - iou_coef: 0.1268 - val_loss: 0.9159 - val_iou_coef: 0.0448
# Epoch 16/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.7429 - iou_coef: 0.1367 - val_loss: 0.9177 - val_iou_coef: 0.0439
# Epoch 17/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.7247 - iou_coef: 0.1463 - val_loss: 0.9105 - val_iou_coef: 0.0478
# Epoch 18/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.7048 - iou_coef: 0.1573 - val_loss: 0.9061 - val_iou_coef: 0.0505
# Epoch 19/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.6865 - iou_coef: 0.1664 - val_loss: 0.8876 - val_iou_coef: 0.0611
# Epoch 20/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.6697 - iou_coef: 0.1773 - val_loss: 0.8789 - val_iou_coef: 0.0666
# Epoch 21/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.6521 - iou_coef: 0.1877 - val_loss: 0.8568 - val_iou_coef: 0.0804
# Epoch 22/100
# 100/100 [==============================] - 32s 317ms/step - loss: 0.6393 - iou_coef: 0.1971 - val_loss: 0.8458 - val_iou_coef: 0.0871
# Epoch 23/100
# 100/100 [==============================] - 32s 318ms/step - loss: 0.6269 - iou_coef: 0.2036 - val_loss: 0.8320 - val_iou_coef: 0.0968
# Epoch 24/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.6124 - iou_coef: 0.2122 - val_loss: 0.8308 - val_iou_coef: 0.0974
# Epoch 25/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.6045 - iou_coef: 0.2188 - val_loss: 0.8178 - val_iou_coef: 0.1070
# Epoch 26/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5965 - iou_coef: 0.2226 - val_loss: 0.8105 - val_iou_coef: 0.1112
# Epoch 27/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5854 - iou_coef: 0.2307 - val_loss: 0.8144 - val_iou_coef: 0.1097
# Epoch 28/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5797 - iou_coef: 0.2354 - val_loss: 0.8044 - val_iou_coef: 0.1147
# Epoch 29/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.5704 - iou_coef: 0.2396 - val_loss: 0.8030 - val_iou_coef: 0.1174
# Epoch 30/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.6016 - iou_coef: 0.2239 - val_loss: 0.7965 - val_iou_coef: 0.1210
# Epoch 31/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.5596 - iou_coef: 0.2491 - val_loss: 0.8029 - val_iou_coef: 0.1184
# Epoch 32/100
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5564 - iou_coef: 0.2509 - val_loss: 0.8074 - val_iou_coef: 0.1144
# Epoch 33/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.5522 - iou_coef: 0.2531 - val_loss: 0.7837 - val_iou_coef: 0.1308
# Epoch 34/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.5490 - iou_coef: 0.2564 - val_loss: 0.7870 - val_iou_coef: 0.1272
# Epoch 35/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5445 - iou_coef: 0.2600 - val_loss: 0.8036 - val_iou_coef: 0.1170
# Epoch 36/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5418 - iou_coef: 0.2613 - val_loss: 0.7993 - val_iou_coef: 0.1204
# Epoch 37/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5390 - iou_coef: 0.2643 - val_loss: 0.7772 - val_iou_coef: 0.1347
# Epoch 38/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.5358 - iou_coef: 0.2679 - val_loss: 0.7811 - val_iou_coef: 0.1329
# Epoch 39/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.5316 - iou_coef: 0.2715 - val_loss: 0.7868 - val_iou_coef: 0.1304
# Epoch 40/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5297 - iou_coef: 0.2737 - val_loss: 0.8027 - val_iou_coef: 0.1191
# Epoch 41/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5257 - iou_coef: 0.2740 - val_loss: 0.7846 - val_iou_coef: 0.1297
# Epoch 42/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5265 - iou_coef: 0.2750 - val_loss: 0.7973 - val_iou_coef: 0.1236
# Epoch 43/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5246 - iou_coef: 0.2762 - val_loss: 0.7963 - val_iou_coef: 0.1240
# Epoch 44/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5220 - iou_coef: 0.2801 - val_loss: 0.8048 - val_iou_coef: 0.1192
# Epoch 45/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5192 - iou_coef: 0.2824 - val_loss: 0.7709 - val_iou_coef: 0.1392
# Epoch 46/100
# 100/100 [==============================] - 32s 325ms/step - loss: 0.5180 - iou_coef: 0.2816 - val_loss: 0.7997 - val_iou_coef: 0.1226
# Epoch 47/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.5163 - iou_coef: 0.2842 - val_loss: 0.7792 - val_iou_coef: 0.1354
# Epoch 48/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.5163 - iou_coef: 0.2845 - val_loss: 0.7777 - val_iou_coef: 0.1358
# Epoch 49/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5130 - iou_coef: 0.2880 - val_loss: 0.7909 - val_iou_coef: 0.1273
# Epoch 50/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5132 - iou_coef: 0.2908 - val_loss: 0.7858 - val_iou_coef: 0.1332
# Epoch 51/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.5098 - iou_coef: 0.2921 - val_loss: 0.7633 - val_iou_coef: 0.1455
# Epoch 52/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5113 - iou_coef: 0.2925 - val_loss: 0.7937 - val_iou_coef: 0.1279
# Epoch 53/100
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5106 - iou_coef: 0.2934 - val_loss: 0.8088 - val_iou_coef: 0.1162
# Epoch 54/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.5073 - iou_coef: 0.2954 - val_loss: 0.7668 - val_iou_coef: 0.1431
# Epoch 55/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5033 - iou_coef: 0.3010 - val_loss: 0.7929 - val_iou_coef: 0.1274
# Epoch 56/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.5028 - iou_coef: 0.3000 - val_loss: 0.7869 - val_iou_coef: 0.1311
# Epoch 57/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.5021 - iou_coef: 0.3010 - val_loss: 0.7894 - val_iou_coef: 0.1294
# Epoch 58/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.5024 - iou_coef: 0.3022 - val_loss: 0.8013 - val_iou_coef: 0.1226
# Epoch 59/100
# 100/100 [==============================] - 32s 317ms/step - loss: 0.5002 - iou_coef: 0.3048 - val_loss: 0.7741 - val_iou_coef: 0.1385
# Epoch 60/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4984 - iou_coef: 0.3070 - val_loss: 0.7964 - val_iou_coef: 0.1248
# Epoch 61/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4992 - iou_coef: 0.3073 - val_loss: 0.7783 - val_iou_coef: 0.1355
# Epoch 62/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4967 - iou_coef: 0.3102 - val_loss: 0.7917 - val_iou_coef: 0.1267
# Epoch 63/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.4957 - iou_coef: 0.3135 - val_loss: 0.7746 - val_iou_coef: 0.1381
# Epoch 64/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.4951 - iou_coef: 0.3143 - val_loss: 0.7853 - val_iou_coef: 0.1319
# Epoch 65/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.4944 - iou_coef: 0.3147 - val_loss: 0.7907 - val_iou_coef: 0.1301
# Epoch 66/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4913 - iou_coef: 0.3177 - val_loss: 0.8016 - val_iou_coef: 0.1223
# Epoch 67/100
# 100/100 [==============================] - 33s 325ms/step - loss: 0.4939 - iou_coef: 0.3159 - val_loss: 0.7570 - val_iou_coef: 0.1527
# Epoch 68/100
# 100/100 [==============================] - 32s 324ms/step - loss: 0.4908 - iou_coef: 0.3205 - val_loss: 0.8165 - val_iou_coef: 0.1127
# Epoch 69/100
# 100/100 [==============================] - 32s 324ms/step - loss: 0.4910 - iou_coef: 0.3205 - val_loss: 0.7893 - val_iou_coef: 0.1315
# Epoch 70/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4891 - iou_coef: 0.3241 - val_loss: 0.7676 - val_iou_coef: 0.1436
# Epoch 71/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4884 - iou_coef: 0.3246 - val_loss: 0.7861 - val_iou_coef: 0.1336
# Epoch 72/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4863 - iou_coef: 0.3273 - val_loss: 0.7707 - val_iou_coef: 0.1418
# Epoch 73/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4867 - iou_coef: 0.3305 - val_loss: 0.7798 - val_iou_coef: 0.1363
# Epoch 74/100
# 100/100 [==============================] - 32s 322ms/step - loss: 0.4863 - iou_coef: 0.3300 - val_loss: 0.8120 - val_iou_coef: 0.1161
# Epoch 75/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4860 - iou_coef: 0.3313 - val_loss: 0.7822 - val_iou_coef: 0.1361
# Epoch 76/100
# 100/100 [==============================] - 32s 318ms/step - loss: 0.4860 - iou_coef: 0.3326 - val_loss: 0.7904 - val_iou_coef: 0.1316
# Epoch 77/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.4837 - iou_coef: 0.3359 - val_loss: 0.7863 - val_iou_coef: 0.1307
# Epoch 78/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4830 - iou_coef: 0.3370 - val_loss: 0.8005 - val_iou_coef: 0.1239
# Epoch 79/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.4821 - iou_coef: 0.3387 - val_loss: 0.7829 - val_iou_coef: 0.1348
# Epoch 80/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4821 - iou_coef: 0.3385 - val_loss: 0.8516 - val_iou_coef: 0.0928
# Epoch 81/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4802 - iou_coef: 0.3421 - val_loss: 0.8831 - val_iou_coef: 0.0737
# Epoch 82/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4826 - iou_coef: 0.3436 - val_loss: 0.8096 - val_iou_coef: 0.1183
# Epoch 83/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4784 - iou_coef: 0.3457 - val_loss: 0.7979 - val_iou_coef: 0.1261
# Epoch 84/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4787 - iou_coef: 0.3468 - val_loss: 0.7813 - val_iou_coef: 0.1365
# Epoch 85/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4774 - iou_coef: 0.3474 - val_loss: 0.7751 - val_iou_coef: 0.1420
# Epoch 86/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4777 - iou_coef: 0.3522 - val_loss: 0.7640 - val_iou_coef: 0.1488
# Epoch 87/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4786 - iou_coef: 0.3520 - val_loss: 0.7925 - val_iou_coef: 0.1313
# Epoch 88/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.4760 - iou_coef: 0.3537 - val_loss: 0.7903 - val_iou_coef: 0.1297
# Epoch 89/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4767 - iou_coef: 0.3520 - val_loss: 0.7922 - val_iou_coef: 0.1308
# Epoch 90/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4757 - iou_coef: 0.3547 - val_loss: 0.7943 - val_iou_coef: 0.1287
# Epoch 91/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.4758 - iou_coef: 0.3570 - val_loss: 0.7900 - val_iou_coef: 0.1291
# Epoch 92/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4751 - iou_coef: 0.3567 - val_loss: 0.7739 - val_iou_coef: 0.1433
# Epoch 93/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.4741 - iou_coef: 0.3589 - val_loss: 0.7873 - val_iou_coef: 0.1316
# Epoch 94/100
# 100/100 [==============================] - 32s 324ms/step - loss: 0.4733 - iou_coef: 0.3608 - val_loss: 0.8130 - val_iou_coef: 0.1170
# Epoch 95/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.4729 - iou_coef: 0.3609 - val_loss: 0.7830 - val_iou_coef: 0.1388
# Epoch 96/100
# 100/100 [==============================] - 32s 323ms/step - loss: 0.4727 - iou_coef: 0.3585 - val_loss: 0.7943 - val_iou_coef: 0.1271
# Epoch 97/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4718 - iou_coef: 0.3632 - val_loss: 0.7989 - val_iou_coef: 0.1249
# Epoch 98/100
# 100/100 [==============================] - 32s 319ms/step - loss: 0.4703 - iou_coef: 0.3644 - val_loss: 0.7759 - val_iou_coef: 0.1438
# Epoch 99/100
# 100/100 [==============================] - 32s 320ms/step - loss: 0.4681 - iou_coef: 0.3681 - val_loss: 0.7806 - val_iou_coef: 0.1411
# Epoch 100/100
# 100/100 [==============================] - 32s 321ms/step - loss: 0.4675 - iou_coef: 0.3696 - val_loss: 0.7738 - val_iou_coef: 0.1434

# %%
# Save the trained and compiled model to a file
model.save(model_path)

# %% [markdown]
# ## Apply Model and Check Results

# %% [markdown]
# #### Check performance at training

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'iou_coef', 'val_loss', 'val_iou_coef'])

# %%
jac = history.history['iou_coef']
val_jac = history.history['val_iou_coef']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs_range = range(1, len(jac) + 1)
fig, ax = plt.subplots(figsize=(15, 8))
ax.plot(epochs_range, jac, 'bo', c='red', label='Training acc')
ax.plot(epochs_range, val_jac, 'b', c='blue', label='Validation acc')
ax.set_title('Training and validation accuracy', fontsize=16)
ax.set_xlabel('epochs_range')
ax.set_ylabel('jac')
ax.legend()

# %%
epochs_range = range(1, len(jac) + 1)
fig, ax = plt.subplots(figsize=(15, 8))
ax.plot(epochs_range, loss, 'bo', c='red', label='Training loss')
ax.plot(epochs_range, val_loss, 'b', c='blue', label='Validation loss')
ax.set_title('Training and validation loss', fontsize=16)
ax.set_xlabel('epochs_range')
ax.set_ylabel('loss')
ax.legend()

# %%
model = load_model(model_path, compile=False)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0218 17:50:52.450381 140283742373376 deprecation.py:506] From /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0218 17:50:52.452135 140283742373376 deprecation.py:506] From /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0218 17:50:52.456191 140283742373376 deprecation.py:506] From /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0218 17:50:52.486185 140283742373376 deprecation.py:506] From /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0218 17:50:52.531667 140283742373376 deprecation.py:506] From /home/stewartchris/project/pythonvirtualenv/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1633: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# Apply model to new data
prediction = model.predict(sents, verbose=1)
# Out:
# 4782/4782 [==============================] - 5s 1ms/sample

# %%
# convert deep learning output to boolean mask
prediction[prediction >= 0.5] = 1
prediction[prediction < 0.5] = 0
maskPred = prediction.astype(bool)

# %%
# replace original mask patches with predicted patches (i.e. to recreate 
# rectangular image, with no data padding around vector cutline)
indboo = np.isin(ipatches, ids) # boolean index
indnor = np.where(indboo == True) # normal index
mpatches_pred = mpatches.copy()
mpatches_pred[indnor,...] = prediction

# %%
# function to reconstruct image from patches
def reconstruct(orig2d, patches3d, window):
    n_x = (orig2d.shape[0] - window) // window + 1
    n_y = (orig2d.shape[1] - window) // window + 1
    reconstructed = np.zeros([n_x*window, n_y*window])
    for i in range(n_x):
        for j in range(n_y):
            reconstructed[i*window:(i+1)*window, j*window:(j+1)*window] = patches3d[j+(i*n_y), ...]
    recon_orig_size = np.zeros(orig2d.shape)
    recon_orig_size[:reconstructed.shape[0], :reconstructed.shape[1]] = reconstructed
    return recon_orig_size

# %%
# ensure prediction has correct dimension and apply function to reconstruct image from patches
pred3d = np.squeeze(mpatches_pred)
recon_orig_size = reconstruct(mask_orig, pred3d, window)

# %%
# check results
plt.figure(figsize=(20, 18))
plt.imshow(recon_orig_size, cmap='gray')

# %%
# Save output to image

with rasterio.open(mask_path) as src:
    profile = src.profile
    profile.update(dtype=rasterio.float64, count=1)

with rasterio.open(pred_path, 'w', **profile) as dst:
    dst.write(recon_orig_size.astype(rasterio.float64), 1)
